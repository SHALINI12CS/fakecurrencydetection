# %% [markdown]
# <a href="https://colab.research.google.com/github/SHALINI12CS/fakecurrencydetection/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipyplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipyplot
#   Downloading ipyplot-1.1.1-py3-none-any.whl (13 kB)
# Collecting shortuuid
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from ipyplot) (7.34.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from ipyplot) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ipyplot) (1.22.4)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (67.7.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (2.14.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (3.0.38)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->ipyplot) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->ipyplot) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->ipyplot) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->ipyplot) (0.2.6)
# Installing collected packages: shortuuid, jedi, ipyplot
# Successfully installed ipyplot-1.1.1 jedi-0.18.2 shortuuid-1.0.11

# %%
# !pip install imgaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.25.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug) (4.7.0.72)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.10.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.0.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug) (0.19.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (23.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (3.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (2023.4.12)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (0.11.0)

# %%
# !pip install imgaug.augmenters
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement imgaug.augmenters (from versions: none)
# ERROR: No matching distribution found for imgaug.augmenters

# %%
import imageio.v3 as iio
import imgaug as ia
import imgaug.augmenters as iaa
import ipyplot
import random
input_img = iio.imread('/content/5b fake1 back.png')
#Horizontal Flip
hflip= iaa.Fliplr(p=1.0)
input_hf= hflip.augment_image(input_img)
#Vertical Flip
vflip= iaa.Flipud(p=1.0)
input_vf= vflip.augment_image(input_img)
images_list=[input_img, input_hf, input_vf]
labels = ['Original', 'Horizontally flipped', 'Vertically flipped']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
rot1 = iaa.Affine(rotate=(-50,20))
input_rot1 = rot1.augment_image(input_img)
images_list=[input_img, input_rot1]
labels = ['Original', 'Rotated Image']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
crop1 = iaa.Crop(percent=(0, 0.3))
input_crop1 = crop1.augment_image(input_img)
images_list=[input_img, input_crop1]
labels = ['Original', 'Cropped Image']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
noise=iaa.AdditiveGaussianNoise(10,40)
input_noise=noise.augment_image(input_img)
images_list=[input_img, input_noise]
labels = ['Original', 'Gaussian Noise Image']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
shear = iaa.Affine(shear=(-40,40))
input_shear=shear.augment_image(input_img)
images_list=[input_img, input_shear]
labels = ['Original', 'Image Shearing']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
contrast=iaa.GammaContrast((0.5, 2.0))
contrast_sig = iaa.SigmoidContrast(gain=(5, 10), cutoff=(0.4, 0.6))
contrast_lin = iaa.LinearContrast((0.6, 0.4))
input_contrast = contrast.augment_image(input_img)
sigmoid_contrast = contrast_sig.augment_image(input_img)
linear_contrast = contrast_lin.augment_image(input_img)
images_list=[input_img, input_contrast,sigmoid_contrast,linear_contrast]
labels = ['Original', 'Gamma Contrast','SigmoidContrast','LinearContrast']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
elastic = iaa.ElasticTransformation(alpha=60.0, sigma=4.0)
polar = iaa.WithPolarWarping(iaa.CropAndPad(percent=(-0.2, 0.7)))
jigsaw = iaa.Jigsaw(nb_rows=20, nb_cols=15, max_steps=(3, 7))
input_elastic = elastic.augment_image(input_img)
input_polar = polar.augment_image(input_img)
input_jigsaw = jigsaw.augment_image(input_img)
images_list=[input_img, input_elastic,input_polar,input_jigsaw]
labels = ['Original', 'elastic','polar','jigsaw']
ipyplot.plot_images(images_list,labels=labels,img_width=180)
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(20,5))
fig.canvas.manager.set_window_title("imgaug.imshow(%s)"%(input_img.shape,))
import albumentations as A
import cv2
#HorizontalFlip
transform = A.HorizontalFlip(p=0.5)
augmented_image = transform(image=input_img)['image']
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(augmented_image)

#VerticalFlip
transform = A.VerticalFlip(p=1)
augmented_image = transform(image=input_img)['image']
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(augmented_image)
transform = A.ShiftScaleRotate(p=0.5)
random.seed(7)
augmented_image = transform(image=input_img)['image']
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(augmented_image)
from albumentations.augmentations.transforms import ChannelShuffle
transform = ChannelShuffle(p=1.0)
random.seed(7)
augmented_image = transform(image=input_img)['image']
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(augmented_image)
from albumentations.augmentations.transforms import Solarize
transform = Solarize(threshold=200,  p=1.0)
augmented_image = transform(image=input_img)['image']
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(augmented_image)
from albumentations.augmentations.transforms import InvertImg
transform = InvertImg(p=1.0)
augmented_image = transform(image=input_img)['image']
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(augmented_image)
# Out:
#         WARNING! Google Colab Environment detected!
#         You might encounter issues while running in Google Colab environment.
#         If images are not displaying properly please try setting `force_b64` param to `True`.
#     <style>
#         #ipyplot-html-viewer-toggle-Vo5sTkEpHYyb6pRocZA5yG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Vo5sTkEpHYyb6pRocZA5yG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Vo5sTkEpHYyb6pRocZA5yG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Vo5sTkEpHYyb6pRocZA5yG:checked ~ #ipyplot-html-viewer-textarea-Vo5sTkEpHYyb6pRocZA5yG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Vo5sTkEpHYyb6pRocZA5yG:checked + #ipyplot-html-viewer-label-Vo5sTkEpHYyb6pRocZA5yG:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Vo5sTkEpHYyb6pRocZA5yG">
#         <label id="ipyplot-html-viewer-label-Vo5sTkEpHYyb6pRocZA5yG" for="ipyplot-html-viewer-toggle-Vo5sTkEpHYyb6pRocZA5yG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Vo5sTkEpHYyb6pRocZA5yG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-HtiKzAgjk6eqa2bHmVb4BA {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HtiKzAgjk6eqa2bHmVb4BA">
#     <div class="ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA">
#         <div id="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-TJdq4w3ZLGkavn7keQuxgL" class="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-TJdq4w3ZLGkavn7keQuxgL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA">
#         <div id="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-PpHg85BKpTzQYKDx8vwnTp" class="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Horizontally flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-PpHg85BKpTzQYKDx8vwnTp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA">
#         <div id="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-5j8cwBoWfKST452ZgDgzNQ" class="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertically flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-5j8cwBoWfKST452ZgDgzNQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-HtiKzAgjk6eqa2bHmVb4BA {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-HtiKzAgjk6eqa2bHmVb4BA">
#     <div class="ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA">
#         <div id="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-TJdq4w3ZLGkavn7keQuxgL" class="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-TJdq4w3ZLGkavn7keQuxgL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA">
#         <div id="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-PpHg85BKpTzQYKDx8vwnTp" class="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Horizontally flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-PpHg85BKpTzQYKDx8vwnTp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-HtiKzAgjk6eqa2bHmVb4BA">
#         <div id="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-5j8cwBoWfKST452ZgDgzNQ" class="ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Vertically flipped</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-HtiKzAgjk6eqa2bHmVb4BA-5j8cwBoWfKST452ZgDgzNQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-gUKEVQvDGu82kXvCV35Kus {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gUKEVQvDGu82kXvCV35Kus {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gUKEVQvDGu82kXvCV35Kus {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle

#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6NTZQttkKx5WovFVdMHw7u:checked ~ #ipyplot-html-viewer-textarea-6NTZQttkKx5WovFVdMHw7u {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6NTZQttkKx5WovFVdMHw7u:checked + #ipyplot-html-viewer-label-6NTZQttkKx5WovFVdMHw7u:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-6NTZQttkKx5WovFVdMHw7u">
#         <label id="ipyplot-html-viewer-label-6NTZQttkKx5WovFVdMHw7u" for="ipyplot-html-viewer-toggle-6NTZQttkKx5WovFVdMHw7u">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-6NTZQttkKx5WovFVdMHw7u" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-EA2zMYtinGwh47gNFH5osM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EA2zMYtinGwh47gNFH5osM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EA2zMYtinGwh47gNFH5osM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EA2zMYtinGwh47gNFH5osM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EA2zMYtinGwh47gNFH5osM">
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-2JaBWwyuHi39zxpAEFYgGb" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-2JaBWwyuHi39zxpAEFYgGb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-4XEm5GCw6qF3mFXMyzvsZo" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gamma Contrast</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-4XEm5GCw6qF3mFXMyzvsZo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-396ytEJzYfPdMaQj3pfuAT" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">SigmoidContrast</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-396ytEJzYfPdMaQj3pfuAT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-La5XcBwrMJ2rr5QTvDJin2" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">LinearContrast</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-La5XcBwrMJ2rr5QTvDJin2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-EA2zMYtinGwh47gNFH5osM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EA2zMYtinGwh47gNFH5osM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EA2zMYtinGwh47gNFH5osM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EA2zMYtinGwh47gNFH5osM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EA2zMYtinGwh47gNFH5osM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EA2zMYtinGwh47gNFH5osM">
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-2JaBWwyuHi39zxpAEFYgGb" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-2JaBWwyuHi39zxpAEFYgGb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-4XEm5GCw6qF3mFXMyzvsZo" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gamma Contrast</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-4XEm5GCw6qF3mFXMyzvsZo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-396ytEJzYfPdMaQj3pfuAT" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">SigmoidContrast</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-396ytEJzYfPdMaQj3pfuAT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EA2zMYtinGwh47gNFH5osM">
#         <div id="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-La5XcBwrMJ2rr5QTvDJin2" class="ipyplot-content-div-EA2zMYtinGwh47gNFH5osM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">LinearContrast</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EA2zMYtinGwh47gNFH5osM-La5XcBwrMJ2rr5QTvDJin2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# /usr/local/lib/python3.10/dist-packages/ipyplot/_utils.py:97: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.asarray(seq)
#     <style>
#         #ipyplot-html-viewer-toggle-QsTU4RVhWotgZcvatQ7t9h {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QsTU4RVhWotgZcvatQ7t9h {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QsTU4RVhWotgZcvatQ7t9h {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QsTU4RVhWotgZcvatQ7t9h:checked ~ #ipyplot-html-viewer-textarea-QsTU4RVhWotgZcvatQ7t9h {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QsTU4RVhWotgZcvatQ7t9h:checked + #ipyplot-html-viewer-label-QsTU4RVhWotgZcvatQ7t9h:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QsTU4RVhWotgZcvatQ7t9h">
#         <label id="ipyplot-html-viewer-label-QsTU4RVhWotgZcvatQ7t9h" for="ipyplot-html-viewer-toggle-QsTU4RVhWotgZcvatQ7t9h">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QsTU4RVhWotgZcvatQ7t9h" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-iUxKsxCt5nxekdMTxNuNoc {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iUxKsxCt5nxekdMTxNuNoc">
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-Wy4vuLBcEsacGKzpNwdoXh" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-Wy4vuLBcEsacGKzpNwdoXh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-25aJ2GRBoVUEpVyTDdtK4E" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">elastic</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-25aJ2GRBoVUEpVyTDdtK4E">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-8dB4WZvvWBE6uyFBb3qyN2" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">polar</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-8dB4WZvvWBE6uyFBb3qyN2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-NygVpK5teQGJGUm3K2CQwE" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">jigsaw</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-NygVpK5teQGJGUm3K2CQwE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-iUxKsxCt5nxekdMTxNuNoc {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc {
#             width: 180px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc {
#             width: 180px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc img {
#             width: 180px;
#         }
#
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iUxKsxCt5nxekdMTxNuNoc">
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-Wy4vuLBcEsacGKzpNwdoXh" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Original</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-Wy4vuLBcEsacGKzpNwdoXh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-25aJ2GRBoVUEpVyTDdtK4E" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">elastic</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-25aJ2GRBoVUEpVyTDdtK4E">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-8dB4WZvvWBE6uyFBb3qyN2" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">polar</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-8dB4WZvvWBE6uyFBb3qyN2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iUxKsxCt5nxekdMTxNuNoc">
#         <div id="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-NygVpK5teQGJGUm3K2CQwE" class="ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">jigsaw</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iUxKsxCt5nxekdMTxNuNoc-NygVpK5teQGJGUm3K2CQwE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
